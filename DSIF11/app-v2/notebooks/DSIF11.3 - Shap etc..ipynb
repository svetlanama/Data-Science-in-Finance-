# %% [markdown]
# # SHAP etc.

# %% [markdown]
# ## Set up

# %% [markdown]
# #### User-specified parameters

# %%
python_material_folder_name = "python-material"

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Check if in Google Colab environment
try:
    from google.colab import drive
    # Mount drive
    drive.mount('/content/drive')
    # Set up path to Python material parent folder
    path_python_material = rf"drive/MyDrive/{python_material_folder_name}"
        # If unsure, print current directory path by executing the following in a new cell:
        # !pwd
    IN_COLAB = True
except:
    IN_COLAB = False
    # If working locally on Jupyter Notebook, parent folder is one folder up (assuming you are using the folder structure shared at the beginning of the course)
    path_python_material = ".."

# %%
if IN_COLAB == True:
  # !pip install fastapi uvicorn

# %% [markdown]
# ## Data import

# %%
# Build quick model here for fraud data
import pandas as pd

df = pd.read_csv(f"{path_python_material}/data/1-raw/dsif11-fraud-detection/synthetic_transaction_data.csv")
df.head()
# Out:
#    transaction_amount transaction_date  transaction_time  customer_age  \
# 0           46.926809       2023-02-09             55817            43
# 1          301.012143       2023-01-28              9356            60
# 2          131.674569       2023-11-13             33099            33
# 3           91.294255       2023-03-26              3190            18
# 4           16.962487       2023-12-07             13332            49
#
#    customer_balance  is_fraud
# 0       9143.802446         0
# 1       3126.627558         0
# 2       4316.836831         0
# 3       4235.945356         0
# 4       5491.237144         0

# %%
df.shape
# Out:
# (100000, 6)

# %% [markdown]
# # dsif11app.py
#
# ### set up

# %%
model_id = "lr1"
import pickle 
import shap

transaction_amount = 20000
customer_age = 20
customer_balance = 20000

data_point = [[
        transaction_amount,
        customer_age,
        customer_balance
    ]]

# %%
# Load the pipeline
with open(f"{path_python_material}/models/{model_id}-pipeline.pkl", "rb") as f:
    loaded_pipeline = pickle.load(f)

# %%
# Shap values
path = f"{path_python_material}/data/2-intermediate/dsif11-X_train_scaled.npy"
print(path)
X_train_scaled = np.load(path) #pd.DataFrame(np.load(path))

explainer = shap.LinearExplainer(loaded_pipeline[1], X_train_scaled)
shap_values = explainer.shap_values(data_point)
shap_values
# Out:
# ../data/2-intermediate/dsif11-X_train_scaled.npy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 7
#       4 X_train_scaled = np.load(path) #pd.DataFrame(np.load(path))
#       6 explainer = shap.LinearExplainer(loaded_pipeline[1], X_train_scaled)
# ----> 7 shap_values = explainer.shap_values(data_point)
#       8 shap_values
#
# File /opt/anaconda3/envs/dsif/lib/python3.11/site-packages/shap/explainers/_linear.py:397, in LinearExplainer.shap_values(self, X)
#     394     X = X.values
#     396 # assert isinstance(X, np.ndarray), "Unknown instance type: " + str(type(X))
# --> 397 if len(X.shape) not in (1, 2):
#     398     raise DimensionError("Instance must have 1 or 2 dimensions! Not: %s" % len(X.shape))
#     400 if self.feature_perturbation == "correlation_dependent":
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
loaded_pipeline[1].coef_[0].tolist()
# Out:
# [0.08082133018733867, 0.01474305144781265, -1.1462573317911788]

# %%
X_train_scaled = 
# X_train_scaled.head()

# %%
explainer = shap.LinearExplainer(loaded_pipeline[1], X_train_scaled)

# %% [markdown]
# # dsif11app-fraud-streamlit.py
#
# ### set up

# %%
api_url = "http://localhost:8502"

import streamlit as st
import requests
import numpy as np
import matplotlib.pyplot as plt
import shap

transaction_amount = 20000
customer_age = 20
customer_balance = 20000

data = {
        "transaction_amount": transaction_amount,
        "customer_age": customer_age,
        "customer_balance": customer_balance
    }

# %% [markdown]
# ## if st.button("Predict"):

# %%
response = requests.post(f"{api_url}/predict/",
                         json=data)
result = response.json()
result

# %%
import seaborn as sns

######### SHAP #########
# Extract SHAP values and feature names
shap_values = np.array(result['shap_values'])
features = result['features']

# Bar plot for SHAP values
fig, ax = plt.subplots()
ax.barh(features, shap_values[0])
ax.set_xlabel('SHAP Value (Impact on Model Output)')
sns.pyplot(fig)

# %% [markdown]
# ## if st.button("Show Feature Importance"):

# %%
## Now kick off app from terminal:
## uvicorn dsif11app-fraud:app --reload --port 8502

# %%
import matplotlib.pyplot as plt
response = requests.get(f"{api_url}/feature-importance")
response

# %%
feature_importance = response.json().get('feature_importance', {})
feature_importance

# %%
features = list(feature_importance.keys())
importance = list(feature_importance.values())

# %%
fig, ax = plt.subplots()
ax.barh(features, importance)
ax.set_xlabel('Importance')
ax.set_title('Feature Importance')
st.pyplot(fig)
